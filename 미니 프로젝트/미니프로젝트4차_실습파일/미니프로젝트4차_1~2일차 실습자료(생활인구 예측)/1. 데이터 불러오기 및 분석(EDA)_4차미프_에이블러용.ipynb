# %% [markdown]
# # 안녕하세요^^
# # 미니 프로젝트에 오신 여러분을 환영합니다.
#
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.

# %% [markdown]
# ## 기본 데이터
#
# [기본 데이터]
# * 서울시 특정구 특정동의 생활인구 데이터입니다.
# * data2017.csv
# * data2018.csv
# * data2019.csv
# * data2020.csv
# * data2021.csv
# * data2022.csv
#
#
# * 2017~2021년은 데이터 전부(train data), 2022년은 1~6월(test data)까지 제공합니다.
#
# [변수 소개]
# * index : 날짜
#
# * 시간대 : 0 ~ 23
#
# * 총 생활 인구 수 : 생활 인구 합계
#
# * 각 성별, 연령대 별 생활 인구수

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 'data2017.csv'파일을 'df2017' 변수에 저장하고 그 Shape을 확인하세요.
# * 아래에 'Pandas'를 Import하고 'data2017.csv'파일을 불러오고 Shape을 확인하는 소스코드를 작성하고 실행해보세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
df2017 = pd.read_csv("../data/data2017.csv")

# %%
# 데이터 프레임의 Shape을 확인합니다.
print(df2017.shape)
# Out:
# (8760, 31)

# %% [markdown]
# ---

# %% [markdown]
# # 2. 추가 데이터 불러오기

# %% [markdown]
# #### [실습문제2] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data2018.csv' ~ 'data2021.csv'를 df18 ~ df21로 각각 불러오고, 이미 불러와 있던 df17을 포함하여 'df_total'로 합쳐보세요. 그리고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df2018 = pd.read_csv("../data/data2018.csv", sep=',')
df2019 = pd.read_csv("../data/data2019.csv", sep=',')
df2020 = pd.read_csv("../data/data2020.csv", sep=',')
df2021 = pd.read_csv("../data/data2021.csv", sep=',')

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total = pd.concat([df2017, df2018, df2019, df2020, df2021], ignore_index=True)

# %%
# 데이터 프레임의 Shape을 확인합니다.
df_total.shape
# Out:
# (43512, 31)

# %% [markdown]
# #### [실습문제3] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data2022.csv'를 df_test로 불러오고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_test = pd.read_csv("../data/data2022.csv", sep=',')

# %%
# 데이터 프레임의 Shape을 확인합니다.
df_test.shape
# Out:
# (4344, 31)

# %% [markdown]
# #### [실습문제4] 데이터 확인
# * df_total와 df_test 데이터를 head, tail. describe, info 등을 활용하여 확인하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
display(df_total.head(3))
print("="*200)
display(df_test.head(3))
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  31535.2200      1945.4402         566.4588
# 1  20170101      1  31188.9174      1930.4766         562.1018
# 2  20170101      2  31240.4974      1921.1864         559.3965
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         631.5581         991.9184        1297.1287        1223.1529
# 1         625.2151        1030.6281        1307.7381        1183.0956
# 2         658.7463        1058.7082        1311.9591        1186.2600
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1552.9448  ...        1157.6661        1107.6781        1282.9235
# 1        1491.5827  ...        1120.0051        1102.5198        1271.8997
# 2        1537.3732  ...        1103.1547        1112.4579        1282.9366
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
display(df_total.tail(3))
print("="*200)
display(df_test.tail(3))
# Out:
#           기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 43509  20211231     21  31417.3991      1983.6728         577.5909
# 43510  20211231     22  30763.0563      2028.3314         590.5941
# 43511  20211231     23  30404.2740      1903.8825         554.3582
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 43509         639.2174         779.6693        1187.6783        1375.6785
# 43510         654.0295         790.1638        1133.6311        1362.0266
# 43511         615.0753         772.8499        1136.6157        1295.0434
#
#        남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# 43509        1600.9946  ...        1186.6502        1348.7581
# 43510        1548.7366  ...        1108.3915        1260.6435
# 43511        1549.1984  ...         993.5635        1166.8245
#
#        여자35세부터39세생활인구수  여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  \
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
display(df_total.describe())
print("="*200)
display(df_test.describe())
# Out:
#               기준일ID         시간대구분        총생활인구수  남자0세부터9세생활인구수  \
# count  4.351200e+04  43512.000000  43512.000000   43512.000000
# mean   2.019067e+07     11.500000  37390.662860    2148.116383
# std    1.419499e+04      6.922266   4310.755449     300.500034
# min    2.017010e+07      0.000000  27011.574900    1256.222800
# 25%    2.018033e+07      5.750000  33875.737425    1949.556800
# 50%    2.019063e+07     11.500000  36894.775800    2110.842250
# 75%    2.020100e+07     17.250000  40337.888175    2319.439625
# max    2.021123e+07     23.000000  55160.667300    5732.894600
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# count     43512.000000     43512.000000     43512.000000     43512.000000
# mean        625.472466       780.302694      1281.098112      1527.965879
# std          87.497350       133.564721       254.313828       243.519957
# min         365.777800       433.762600       638.408000       944.904700
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
display(df_total.info())
print("="*200)
display(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43512 entries, 0 to 43511
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            43512 non-null  int64
#  1   시간대구분            43512 non-null  int64
#  2   총생활인구수           43512 non-null  float64
#  3   남자0세부터9세생활인구수    43512 non-null  float64
#  4   남자10세부터14세생활인구수  43512 non-null  float64
#  5   남자15세부터19세생활인구수  43512 non-null  float64
#  6   남자20세부터24세생활인구수  43512 non-null  float64
#  7   남자25세부터29세생활인구수  43512 non-null  float64
#  8   남자30세부터34세생활인구수  43512 non-null  float64
#  9   남자35세부터39세생활인구수  43512 non-null  float64
#  10  남자40세부터44세생활인구수  43512 non-null  float64
#  11  남자45세부터49세생활인구수  43512 non-null  float64
#  12  남자50세부터54세생활인구수  43512 non-null  float64
#  13  남자55세부터59세생활인구수  43512 non-null  float64
#  14  남자60세부터64세생활인구수  43512 non-null  float64
#  15  남자65세부터69세생활인구수  43512 non-null  float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 3. 데이터 분석하기
# ## EDA for Feature Engineering
#
# * EDA는 명확한 목적하에, 반드시 workflow에 도움이 되는 결과를 도출해야 함.
# * EDA를 검색해봐도 좋음.
#
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 관측치들의 패턴 탐색
#   * 잘못된 자료들을 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제5] 데이터 형태 변경하기
# * df_total, df_test의 index를 리셋 하고, ['기준일ID']에 to_datetime 함수를 사용하여 데이터 형태를 변경하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total.reset_index(inplace=True, drop=True)
df_test.reset_index(inplace=True, drop=True)

# %%
import pandas as pd

# '기준일ID' 열의 데이터를 문자열로 변환
df_total['기준일ID'] = df_total['기준일ID'].astype(str)
df_test['기준일ID'] = df_test['기준일ID'].astype(str)

# '기준일ID' 열의 문자열을 날짜로 변환
df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'], format='%Y%m%d')
df_test['기준일ID'] = pd.to_datetime(df_test['기준일ID'], format='%Y%m%d')

# %%
df_total
# Out:
#            기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0     2017-01-01      0  31535.2200      1945.4402         566.4588
# 1     2017-01-01      1  31188.9174      1930.4766         562.1018
# 2     2017-01-01      2  31240.4974      1921.1864         559.3965
# 3     2017-01-01      3  31442.4314      1946.4476         566.7525
# 4     2017-01-01      4  31922.7751      1953.7713         568.8845
# ...          ...    ...         ...            ...              ...
# 43507 2021-12-31     19  33060.4555      1858.2611         541.0746
# 43508 2021-12-31     20  32360.1898      2093.8808         609.6807
# 43509 2021-12-31     21  31417.3991      1983.6728         577.5909
# 43510 2021-12-31     22  30763.0563      2028.3314         590.5941
# 43511 2021-12-31     23  30404.2740      1903.8825         554.3582
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0             631.5581         991.9184        1297.1287        1223.1529
# ...

# %% [markdown]
# #### [실습문제6] 데이터 분포 알아보기
# * df_total 및 df_test의 '총생활인구수' 변수를 기준으로 각종 Chart를 그려보고 인사이트를 도출해보세요.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# 경고 메시지 숨기기
warnings.filterwarnings("ignore", category=UserWarning)

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(df_total.corr(),
            annot=True, 
            cmap='YlOrRd', 
            fmt='.2f'
            )
plt.title('Heatmap')
plt.xticks(rotation=45, size = 12)
plt.yticks(size=12) 
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8920\2074121612.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_total.corr(),

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\user\Desktop\KT AIVLE 4기\미프\미니프로젝트4차_실습파일\미니프로젝트4차_실습자료\1. 데이터 불러오기 및 분석(EDA)_4차미프_에이블러용.ipynb 셀 36 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/KT%20AIVLE%204%EA%B8%B0/%EB%AF%B8%ED%94%84/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B84%EC%B0%A8_%EC%8B%A4%EC%8A%B5%ED%8C%8C%EC%9D%BC/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B84%EC%B0%A8_%EC%8B%A4%EC%8A%B5%EC%9E%90%EB%A3%8C/1.%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0%20%EB%B0%8F%20%EB%B6%84%EC%84%9D%28EDA%29_4%EC%B0%A8%EB%AF%B8%ED%94%84_%EC%97%90%EC%9D%B4%EB%B8%94%EB%9F%AC%EC%9A%A9.ipynb#Y164sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ...

# %%
# '총생활인구수'에 대한 히스토그램을 그립니다.
plt.figure(figsize=(10, 6))
plt.hist(df_total['총생활인구수'], bins=30, color='skyblue', edgecolor='black')
plt.title('총생활인구수 분포')
plt.xlabel('총생활인구수')
plt.ylabel('빈도')
plt.show()

# %%
# '총생활인구수'의 평균과 중앙값을 계산하여 출력합니다.
mean_total_population = df_total['총생활인구수'].mean()
median_total_population = df_total['총생활인구수'].median()
print(f'평균 총생활인구수: {mean_total_population:.2f}')
print(f'중앙값 총생활인구수: {median_total_population:.2f}')
# Out:
# 평균 총생활인구수: 37390.66
# 중앙값 총생활인구수: 36894.78

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
target = '총생활인구수'
var = '시간대구분'
plt.figure(figsize=(12,6))
sns.regplot(x=var, y=target, data = df_yu)
plt.grid()
plt.show()

# %%
# '총생활인구수' 분포를 바이옴 분포 그래프로 그립니다.
plt.figure(figsize=(10, 6))
sns.violinplot(data=df_total, y='총생활인구수', color='lightblue')
plt.title('총생활인구수 분포 (바이옴 분포 그래프)')
plt.ylabel('총생활인구수')
plt.show()

# %%
# '총생활인구수' 분포를 밀집도 히트맵으로 그립니다.
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df_total, x='총생활인구수', y=df_total['시간대구분'], cmap='Blues', shade=True)
plt.title('총생활인구수 밀집도 히트맵')
plt.xlabel('총생활인구수')
plt.ylabel('시간대구분')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8920\94464607.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df_total, x='총생활인구수', y=df_total['시간대구분'], cmap='Blues', shade=True)

# %%
# '총생활인구수' 분포를 KDE 플롯으로 그립니다.
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df_total, x='총생활인구수', color='skyblue')
plt.title('총생활인구수 분포 (KDE 플롯)')
plt.xlabel('총생활인구수')
plt.show()

# %%
# 연령대별 생활인구 분포를 확인하기 위한 열 선택
age_columns = df_total.columns[3:-1]  # '남자0세부터9세생활인구수'부터 '여자65세부터69세생활인구수'까지

# 데이터를 '연령대'와 '총생활인구수' 열로 재구성
age_data = pd.melt(df_total, id_vars=['기준일ID'], value_vars=age_columns, var_name='연령대', value_name='총생활인구수')

# 연령대별 분포를 바이옴 분포 그래프로 그립니다.
plt.figure(figsize=(12, 6))
sns.violinplot(data=age_data, x='연령대', y='총생활인구수', palette='husl')
plt.title('연령대별 생활인구 분포')
plt.xlabel('연령대')
plt.ylabel('총생활인구수')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8920\3502789523.py:5: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   age_data = pd.melt(df_total, id_vars=['기준일ID'], value_vars=age_columns, var_name='연령대', value_name='총생활인구수')

# %%
# 연령대별 생활인구 분포를 확인하기 위한 열 선택
age_columns = df_total.columns[3:-1]  # '남자0세부터9세생활인구수'부터 '여자65세부터69세생활인구수'까지

# 데이터를 '연령대'와 '총생활인구수' 열로 재구성
age_data = pd.melt(df_total, id_vars=['기준일ID'], value_vars=age_columns, var_name='연령대', value_name='총생활인구수')

# 연령대별 분포를 박스플롯으로 그립니다.
plt.figure(figsize=(12, 6))
sns.boxplot(data=age_data, x='연령대', y='총생활인구수', palette='husl')
plt.title('연령대별 생활인구 분포 (상자그림)')
plt.xlabel('연령대')
plt.ylabel('총생활인구수')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8920\3455444314.py:5: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   age_data = pd.melt(df_total, id_vars=['기준일ID'], value_vars=age_columns, var_name='연령대', value_name='총생활인구수')

# %% [markdown]
# ## 다음 단계를 위해서 데이터를 저장하겠습니다.

# %%
#CSV 파일로 저장
file_path1 = '../data/df_total.csv'
file_path2 = '../data/df_test.csv'
df_total.to_csv(file_path1, index=False)  
df_test.to_csv(file_path2, index=False)

# %% [markdown]
# # 4. (참고) 시계열 분석 기초 (Stationary / Normality)
#
# * 아래 주어진 코드를 기반으로 해당 데이터가 정상성과 정규성을 충족 하는지 확인해봅시다

# %% [markdown]
# #### [실습문제7] 정상성 분석
# * df_total['총생활인구수'] 데이터가 정상성을 띄는지 확인해보도록 하겠습니다
#
# * 정상성을 띈다 = 시계열 데이터의 평균과 분산이 일정하다.
#     - Dickey Fuller test 를 활용합니다
#     - Stationary (p-value < 0.05)
#
# ---
#
# * 귀무가설 : H0 : 시계열 데이터에 unit root를 포함한다 : nonstatinary / 정상 시계열이 아니다.
# * 대립가설 : H1 : 시계열 데이터에 unit root를 포함하지 않는다 : 정상 시계열이다.
# ---

# %%
import statsmodels.api as sm

from statsmodels.tsa.stattools import adfuller # ADF는 정상성 검정을 위해 사용
from statsmodels.tsa.seasonal import seasonal_decompose # 시계열 요소 분해
from statsmodels.tsa.arima.model import ARIMA # ARIMA 모델, SARIMA 모델

import pmdarima as pm # auto arima

# %%
# 백색잡음 시도표
plt.figure(figsize = (10,3))
x = df_total['총생활인구수']
plt.plot(np.arange(len(df_total)), x)
plt.title('White Noise')
plt.xlabel('period')
plt.show()

# %% [markdown]
# ## Augmented Dicket Fuller Test 단위근 검정(ADF test)

# %% [markdown]
# ### Augmented Dicket Fuller Test 가설검정

# %% [markdown]
# - H0: 정상성이 있는 시계열이 아님(단위근)
# - H1: 정상성이 있는 시계열

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(y):
    dftest = adfuller(y, autolag='AIC')
    # autolag 'AIC' : 검정 AR 모형의 차수를 자동으로 결정
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value ({})'.format(key)] = value
    print(dfoutput)
    #### 결과: p-value: 0.05 미만으로 귀무가설 기각 -> 즉, 정상 시계열

adf_test(df_total['총생활인구수'])
# test statistic 검정 통계량 - 회귀 분석의 결과로 나타나는 계수
# p-value : p-value 추정치
# # of lags : 사용된 시차의 수(used lags)
# # of observations : 분석에 사용된 자료의 수
# critical values : 1%, 5%, 10%수준에 해당되는 검정 통계량의 값

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))

fig = sm.graphics.tsa.plot_acf(x, lags=80, ax=axes[0])
fig = sm.graphics.tsa.plot_pacf(x, lags=80, ax=axes[1], method='ywm')

fig.suptitle('ACF and PACF Graph of White Noise', y = 1.10)
plt.show()

# %% [markdown]
# #### [실습문제8] 정규성 분석
# * df_total['총생활인구수'] 데이터가 정규성을 띄는지 확인해보도록 하겠습니다
#
# * 정규성을 띈다 = 데이터의 분포가 정규분포를 이룬다.
#     * Shapiro test 를 활용합니다
#     * Normality (p-value > 0.05)
#
# ---
# * 귀무가설 : H0 : 시계열 데이터가 정규성을 충족한다.
# * 대립가설 : H1 : 시계열 데이터가 정규성을 충족하지 않는다.
# ---

# %%
from scipy import stats
from scipy.stats import shapiro
shapiro_test = stats.shapiro(df_total['총생활인구수'])
shapiro_test

# %%
# shapiro test의 특징 : 데이터 수가 5000을 초과 하는 경우, 
#                      정규성 검정에 대한 p-value를 담보하지 못한다.(통계적 유의성이 떨어진다.)

# 시계열 데이터가 정규성을 충족하지 않습니다.

# %%
from scipy.stats import anderson
anderson(df_total['총생활인구수'])

# %%
ar_mod = ARIMA(x, order=(7,0,0))
result = ar_mod.fit()
plt.figure(figsize=(10,3))

plt.plot(np.arange(len(df_total)), x)
plt.plot(np.arange(len(df_total)), result.fittedvalues)
plt.show()

# %%
result.summary()

# %% [markdown]
#  - Ljung-Box(Q): 통계량의 귀무가설: **"잔차(Residual)는 백색잡음(White Noise)"**
#  - Jarque-Bera (JB):통계량의 귀무가설: **"잔차(Residual)는 정규성을 만족"**
#
# 잔차가 정규성을 띈다면, skew는0, kurtosis는 3에 가까운 것이 특징

# %%
# MAE는 예측값과 실제값 사이의 절대 오차들의 평균을 나타내는 값으로, 0에 가까울수록 예측 모델이 더 정확하다는 의미를 지닌다.
print('mean absolute error: {:.5f}'.format(result.mae))

# %%
result.plot_diagnostics(figsize=(20, 10))
plt.show()

# %% [markdown]
# ## ARIMA -- I(1)

# %%
i_mod = ARIMA(x, order=(1,1,0))
result = i_mod.fit()
result

# %%
plt.figure(figsize=(15,5))

plt.plot(np.arange(len(df_test)), df_test['총생활인구수'])
plt.plot(np.arange(len(df_test)), result.fittedvalues[:len(df_test)])
plt.show()

# %%
result.summary()

# %% [markdown]
#  - Ljung-Box(Q): 통계량의 귀무가설: **"잔차(Residual)는 백색잡음(White Noise)"**
#  - **귀무가설 기각!!!**
#  - Jarque-Bera (JB):통계량의 귀무가설: **"잔차(Residual)는 정규성을 만족"**

# %%
# MAE는 예측값과 실제값 사이의 절대 오차들의 평균을 나타내는 값으로, 0에 가까울수록 예측 모델이 더 정확하다는 의미를 지닌다.
print('mean absolute error: {}'.format(result.mae))

# %%
# auto arima
pm.arima.auto_arima(x,
                    d=1,
                    start_p=0,
                    max_p=5,
                    start_q=0,
                    max_q=5,
                    seasonal=True,
                    step=True,
                    trace=True
                   )

# %%
# 차분만 이용한 추세 제거 모델링
auto_mod = ARIMA(x, order=(5,1,1))
result = auto_mod.fit()

# %%
plt.figure(figsize=(15,5))

plt.plot(np.arange(len(df_test)), df_test['총생활인구수'])
plt.plot(np.arange(len(df_test)), result.fittedvalues[:len(df_test)])
plt.show()

# %%
result.summary()

# %%
# MAE는 예측값과 실제값 사이의 절대 오차들의 평균을 나타내는 값으로, 0에 가까울수록 예측 모델이 더 정확하다는 의미를 지닌다.
print('mean absolute error: {}'.format(result.mae))

# %% [markdown]
# ### SARIMAX

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
import itertools
import numpy as np

## Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 3)

## Generate all different combinations of p, d and q triplets
pdq = list(itertools.product(p, d, q))

# generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
best_aic = np.inf
best_pdq = None
best_seasonal_pdq = None
tmp_model = None
best_mdl = None

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            tmp_mdl = sm.tsa.statespace.SARIMAX(df_total['총생활인구수'], exog=None, order = param,
                                                seasonal_order = param_seasonal,
                                                enforce_stationarity=True,
                                                enforce_invertibility=True)
            
            res = tmp_mdl.fit()        
            print("SARIMAX{}x{}12 - AIC:{}".format(param, param_seasonal, res.aic))
            if res.aic < best_aic:
                best_aic = res.aic
                best_pdq = param
                best_seasonal_pdq = param_seasonal
                best_mdl = tmp_mdl
        except:
            #print("Unexpected error:", sys.exc_info()[0])
            continue
print("Best SARIMAX{}x{}12 model - AIC:{}".format(best_pdq, best_seasonal_pdq, best_aic))
best_aic = np.inf
best_pdq = None
best_seasonal_pdq = None
tmp_model = None
best_mdl = None

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            tmp_mdl = sm.tsa.statespace.SARIMAX(df_total['총생활인구수'], exog=None, order = param,
                                                seasonal_order = param_seasonal,
                                                enforce_stationarity=True,
                                                enforce_invertibility=True)
            
            res = tmp_mdl.fit()        
            print("SARIMAX{}x{}12 - AIC:{}".format(param, param_seasonal, res.aic))
            if res.aic < best_aic:
                best_aic = res.aic
                best_pdq = param
                best_seasonal_pdq = param_seasonal
                best_mdl = tmp_mdl
        except:
            #print("Unexpected error:", sys.exc_info()[0])
            continue
print("Best SARIMAX{}x{}12 model - AIC:{}".format(best_pdq, best_seasonal_pdq, best_aic))

# %%
mdl = sm.tsa.statespace.SARIMAX(endog=df_total['총생활인구수'], order=(5,1,0),
                                seasonal_order=(1,2,1,12),
                                enforce_invertibility=True,
                                enforce_stationarity=True)
result = mdl.fit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\user\Desktop\KT AIVLE 4기\미프\미니프로젝트4차_실습파일\미니프로젝트4차_실습자료\1. 데이터 불러오기 및 분석(EDA)_4차미프_에이블러용.ipynb 셀 80 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/KT%20AIVLE%204%EA%B8%B0/%EB%AF%B8%ED%94%84/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B84%EC%B0%A8_%EC%8B%A4%EC%8A%B5%ED%8C%8C%EC%9D%BC/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B84%EC%B0%A8_%EC%8B%A4%EC%8A%B5%EC%9E%90%EB%A3%8C/1.%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0%20%EB%B0%8F%20%EB%B6%84%EC%84%9D%28EDA%29_4%EC%B0%A8%EB%AF%B8%ED%94%84_%EC%97%90%EC%9D%B4%EB%B8%94%EB%9F%AC%EC%9A%A9.ipynb#Y152sZmlsZQ%3D%3D?line=0'>1</a> mdl = sm.tsa.statespace.SARIMAX(endog=df_total['총생활인구수'], order=(5,1,0),
# ...

# %%
result.summary()

# %%
result.plot_diagnostics(figsize=(16, 10))
plt.show()

# %%
pred_SARIMAX = result.get_predictiom(start=pd.to_datetime('2021-01-01'),
                                     end=pd.to_datetime('2021.06.30'))

# %%
pred_ci = pred_SARIMAX.conf_int()

## Plot in-sample-prediction
ax = y['1949':].plot(label='Observed',color='#006699');
pred_SARIMAX.predicted_mean.plot(ax=ax, label='One-step Ahead Prediction', alpha=.7, color='#ff0066');

## Draw confidence bound (gray)
ax.fill_between(pred_ci.index, 
                pred_ci.iloc[:, 0], 
                pred_ci.iloc[:, 1], color='#ff0066', alpha=.25);

## style the plot
ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('1958-12-01'), y.index[-1], alpha=.15, zorder=-1, color='grey');
ax.set_xlabel('Date');
ax.set_ylabel('Passengers');
plt.legend(loc='upper left');
plt.show()

# %%
import pmdarima as pm
from statsmodels.tsa.statespace.sarimax import SARIMAX

# SARIMA 모델 생성 및 학습
sarima_model = SARIMAX(df_total['총생활인구수'], order=(5,1,1), trend='c')
sarima_result = sarima_model.fit(disp=False)

# 테스트 데이터에 대한 예측
forecast = sarima_result.get_forecast(steps=len(df_test))
df_test['예측_총생활인구수'] = forecast.predicted_mean
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# 예측 결과 시각화
plt.figure(figsize=(15, 5))
plt.plot(df_test.index, df_test['총생활인구수'], label='실제 데이터')
plt.plot(df_test.index, df_test['예측_총생활인구수'], label='예측 데이터', linestyle='--')
plt.legend()
plt.title('SARIMA 모델 예측 결과')
plt.xlabel('날짜')
plt.ylabel('총생활인구수')
plt.show()
